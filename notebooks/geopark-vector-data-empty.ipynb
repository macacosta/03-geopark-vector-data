# %% [markdown]
# Let's get started working with spatial data! In this notebook you'll learn how to open and plot GeoDataFrames as shapefiles (.shp) in `Python` using the `Geopandas` library. We'll also demonstrate how to make an interactive map using `Folium`.
#
# You can read more about working with **Geopandas** here:
# > * [Earth Data Science Textbook](https://www.earthdatascience.org/courses/use-data-open-source-python/intro-vector-data-python/spatial-data-vector-shapefiles/)
# > * [Geopandas Documentation](https://geopandas.org/en/stable/getting_started/introduction.html)
#
# Read more about **Folium** here:
# > * [Earth Data Science Textbook](https://www.earthdatascience.org/tutorials/introduction-to-leaflet-animated-maps/)
# > * [Folium Documentation](https://python-visualization.github.io/folium/latest/getting_started.html)
#
# From Earth Data Science textbook:
#
# ![](https://www.earthdatascience.org/images/courses/earth-analytics/spatial-data/points-lines-polygons-vector-data-types.png)

# %%
# Import Python libraries
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
# Download Colombia boundary
colombia_boundary_url = ("https://maps.princeton.edu/download/file/tufts-colombia-municipalities-11-shapefile.zip")

# Open Colombia boundary .shp with Geopandas
colombia_gdf = gpd.read_file(colombia_boundary_url)
colombia_gdf
# Out:
#      ID_ESPACIA  AREA_OFICI          ENTIDAD_TE NOM_DEPART  \
# 0         23189      637.49  Cabecera Municipal    CÓRDOBA
# 1         23570      795.00  Cabecera Municipal    CÓRDOBA
# 2         23068     1932.62  Cabecera Municipal    CÓRDOBA
# 3         23580     1650.73  Cabecera Municipal    CÓRDOBA
# 4         23686      472.57  Cabecera Municipal    CÓRDOBA
# ...         ...         ...                 ...        ...
# 1123      23675      335.03  Cabecera Municipal    CÓRDOBA
# 1124      23672      210.75  Cabecera Municipal    CÓRDOBA
# 1125      23168      320.42  Cabecera Municipal    CÓRDOBA
# 1126      23670      212.44  Cabecera Municipal    CÓRDOBA
# 1127      23182      584.90  Cabecera Municipal    CÓRDOBA
#
#                    NOM_MUNICI COD_DEPTO  \
# 0              CIÉNAGA DE ORO        23
# 1                PUEBLO NUEVO        23
# 2                      AYAPEL        23
# 3           PUERTO LIBERTADOR        23
# 4                  SAN PELAYO        23
# ...                       ...       ...
# 1123  SAN BERNARDO DEL VIENTO        23
# 1124               SAN ANTERO        23
# 1125                    CHIMÁ        23
# 1126  SAN ANDRÉS DE SOTAVENTO        23
# 1127                    CHINÚ        23
#
#                                                geometry
# 0     POLYGON ((-75.71080 8.98249, -75.71119 8.98358...
# 1     POLYGON ((-75.25133 8.32489, -75.25144 8.32489...
# 2     POLYGON ((-75.18418 8.39828, -75.18352 8.39893...
# 3     POLYGON ((-75.51257 7.94787, -75.51315 7.94683...
# 4     POLYGON ((-75.71080 8.98249, -75.71024 8.98264...
# ...                                                 ...
# 1123  POLYGON ((-75.86320 9.42472, -75.86318 9.42231...
# 1124  POLYGON ((-75.86320 9.42472, -75.86297 9.42476...
# 1125  POLYGON ((-75.71080 8.98249, -75.71213 8.98212...
# 1126  POLYGON ((-75.57457 9.02304, -75.57458 9.02421...
# 1127  POLYGON ((-75.57457 9.02304, -75.57438 9.02306...
#
# [1128 rows x 7 columns]

# %%
colombia_gdf.plot()
# Out:
# <Axes: >

# %%
# Map using explore 
# colombia_boundary.explore()

# %% [markdown]
# ## **Department Boundaries**

# %%
# Colombia Admin boundaries
dept_url = ("https://stacks.stanford.edu/file/druid:mj028ht5751/data.zip")

# Open data with geopandas
dept_gdf = gpd.read_file(dept_url)
dept_gdf
# Out:
#       ID_0  ISO    NAME_0  ID_1    NAME_1  ID_2             NAME_2    HASC_2  \
# 0       53  COL  Colombia     1  Amazonas     1         El Encanto  CO.AM.EE
# 1       53  COL  Colombia     1  Amazonas     2        La Chorrera  CO.AM.LC
# 2       53  COL  Colombia     1  Amazonas     3         La Pedrera  CO.AM.LP
# 3       53  COL  Colombia     1  Amazonas     4            Leticia  CO.AM.LE
# 4       53  COL  Colombia     1  Amazonas     5      Mirití-Paraná  CO.AM.MI
# ...    ...  ...       ...   ...       ...   ...                ...       ...
# 1060    53  COL  Colombia    32   Vichada  1061       La Primavera  CO.VD.LP
# 1061    53  COL  Colombia    32   Vichada  1062     Puerto Carreño  CO.VD.PC
# 1062    53  COL  Colombia    32   Vichada  1063  San Jose de Ocune     CO.VD
# 1063    53  COL  Colombia    32   Vichada  1064         Santa Rita       NaN
# 1064    53  COL  Colombia    32   Vichada  1065      Santa Rosalía  CO.VD.SR
#
#       CCN_2  CCA_2                      TYPE_2                   ENGTYPE_2  \
# 0         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 1         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 2         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 3         0    NaN                   Municipio                Municipality
# 4         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# ...     ...    ...                         ...                         ...
# 1060      0    NaN                   Municipio                Municipality
# 1061      0    NaN                   Municipio                Municipality
# 1062      0    NaN                   Municipio                Municipality
# 1063      0    NaN                   Municipio                Municipality
# 1064      0    NaN                   Municipio                Municipality
#
#       NL_NAME_2      VARNAME_2  \
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN  Miriti Parana
# ...         ...            ...
# 1060        NaN            NaN
# 1061        NaN            NaN
# 1062        NaN            NaN
# 1063        NaN            NaN
# 1064        NaN            NaN
#
#                                                geometry
# 0     POLYGON ((-73.95367 -1.10172, -73.95241 -1.098...
# 1     POLYGON ((-71.98020 -1.81340, -71.96750 -1.831...
# 2     MULTIPOLYGON (((-72.61586 -0.92313, -72.59810 ...
# 3     POLYGON ((-70.28952 -3.83257, -70.28491 -3.822...
# 4     POLYGON ((-70.21880 -0.48360, -70.20900 -0.489...
# ...                                                 ...
# 1060  POLYGON ((-68.54120 5.43700, -68.55100 5.43360...
# 1061  POLYGON ((-67.49085 6.14925, -67.49323 6.13791...
# 1062  POLYGON ((-71.09520 2.84550, -71.09780 3.34340...
# 1063  POLYGON ((-68.90510 3.65020, -68.87930 3.92910...
# 1064  POLYGON ((-70.38830 4.67342, -70.39980 4.66840...
#
# [1065 rows x 15 columns]

# %%
# Explore department boundary data
dept_gdf.info()

dept_gdf["NAME_2"]
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID_0       1065 non-null   int64
#  1   ISO        1065 non-null   object
#  2   NAME_0     1065 non-null   object
#  3   ID_1       1065 non-null   int64
#  4   NAME_1     1065 non-null   object
#  5   ID_2       1065 non-null   int64
#  6   NAME_2     1065 non-null   object
#  7   HASC_2     1062 non-null   object
#  8   CCN_2      1065 non-null   int64
#  9   CCA_2      0 non-null      float64
#  10  TYPE_2     1056 non-null   object
#  11  ENGTYPE_2  1056 non-null   object
#  12  NL_NAME_2  0 non-null      float64
#  13  VARNAME_2  87 non-null     object
#  14  geometry   1065 non-null   geometry
# dtypes: float64(2), geometry(1), int64(4), object(8)
# memory usage: 124.9+ KB
# 0              El Encanto
# 1             La Chorrera
# 2              La Pedrera
# 3                 Leticia
# 4           Mirití-Paraná
#               ...
# 1060         La Primavera
# 1061       Puerto Carreño
# 1062    San Jose de Ocune
# 1063           Santa Rita
# 1064        Santa Rosalía
# Name: NAME_2, Length: 1065, dtype: object

# %%
# Select Amazonas municipality
amazonas = colombia_gdf[colombia_gdf["NOM_DEPART"] == "AMAZONAS"]
amazonas
# Out:
#    ID_ESPACIA  AREA_OFICI                   ENTIDAD_TE NOM_DEPART  \
# 33      91530     8410.09  Corregimiento Departamental   AMAZONAS
# 34      91263    10690.26  Corregimiento Departamental   AMAZONAS
# 35      91536    13641.05  Corregimiento Departamental   AMAZONAS
# 36      91798     9137.71  Corregimiento Departamental   AMAZONAS
# 37      91001     6186.26                   CAP. DEPTO   AMAZONAS
# 38      91540     1515.58           Cabecera Municipal   AMAZONAS
# 39      91460    16891.79  Corregimiento Departamental   AMAZONAS
# 40      91430     1506.18  Corregimiento Departamental   AMAZONAS
# 41      91405    12738.75  Corregimiento Departamental   AMAZONAS
# 42      91669    14759.22  Corregimiento Departamental   AMAZONAS
# 43      91407    13679.19  Corregimiento Departamental   AMAZONAS
#
#                                         NOM_MUNICI COD_DEPTO  \
# 33             PUERTO ALEGRÍA (Cor. Departamental)        91
# 34                 EL ENCANTO (Cor. Departamental)        91
# 35               PUERTO ARICA (Cor. Departamental)        91
# 36                   TARAPACÁ (Cor. Departamental)        91
# 37                                         LETICIA        91
# 38                                   PUERTO NARIÑO        91
# 39  MIRITÍ-PARANÁ (Campoamor) (Cor. Departamental)        91
# 40        LA VICTORIA (Pacoa) (Cor. Departamental)        91
# 41                LA CHORRERA (Cor. Departamental)        91
# 42     SANTANDER (Araracuara) (Cor. Departamental)        91
# 43                 LA PEDRERA (Cor. Departamental)        91
#
#                                              geometry
# 33  POLYGON ((-74.38851 -0.55351, -74.38102 -0.551...
# 34  POLYGON ((-71.77392 -2.17489, -71.77594 -2.176...
# 35  POLYGON ((-71.77392 -2.17489, -71.77593 -2.171...
# 36  POLYGON ((-69.71428 -3.00261, -69.71601 -3.002...
# 37  POLYGON ((-69.71428 -3.00261, -69.88301 -3.940...
# 38  POLYGON ((-70.33734 -3.20082, -70.33744 -3.211...
# 39  POLYGON ((-71.99610 -0.26831, -71.98758 -0.268...
# 40  POLYGON ((-71.44949 0.02042, -71.44805 0.02046...
# 41  POLYGON ((-71.99031 -1.53227, -71.99052 -1.553...
# 42  POLYGON ((-70.72647 -1.43024, -70.73084 -1.434...
# 43  POLYGON ((-69.43422 -1.07068, -69.43131 -1.072...

# %%
# Select Puerto Nariño
pn = amazonas[amazonas["NOM_MUNICI"] == "PUERTO NARIÑO"]
pn
# Out:
#    ID_ESPACIA  AREA_OFICI          ENTIDAD_TE NOM_DEPART     NOM_MUNICI  \
# 38      91540     1515.58  Cabecera Municipal   AMAZONAS  PUERTO NARIÑO
#
#    COD_DEPTO                                           geometry
# 38        91  POLYGON ((-70.33734 -3.20082, -70.33744 -3.211...

# %%
pn.plot()
# Out:
# <Axes: >

# %%
# Create an interactive map of the Colombia boundaries using .explore()
colombia_gdf.explore()

# %%
# Plot the geodataframe using Matplotlib
fig, ax = plt.subplots(figsize=(12,20))
colombia_gdf.plot(ax=ax,
         edgecolor='black',
         color='beige')
plt.title('Level 2 Admin Boundaries of Colombia', fontsize=20)
plt.show()

# %% [markdown]
# ## **Petroleum & Gas (2013)**

# %%
# Oil & Gas (point shapefile)

# Citation: Petroleum and Gas Extraction Sites Colombia 2013. [Shapefile].
# Sistema de Inforrmacion Ambiental de Colombia (SIAC).
# Retrieved from https://maps.princeton.edu/catalog/tufts-colombia-petroleumgasexplotation-sites-13

oil_url = ("https://maps.princeton.edu/download/file/tufts-colombia-petroleumgasexplotation-sites-13-shapefile.zip")

# Open the oil and gas data using geopandas
oil_gdf = gpd.read_file(oil_url)
oil_gdf
# Out:
#         CORPORACIO    DEPTO       ESTADO      EXP       FECHA  \
# 0    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 1    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 2    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 3       CORPOCESAR    CESAR  SEGUIMIENTO  LAM4539  21/12/2009
# 4       CORPOCESAR    CESAR  SEGUIMIENTO  LAM4539  21/12/2009
# ..             ...      ...          ...      ...         ...
# 941            CAM    HUILA  SEGUIMIENTO  LAM3703  07/06/2007
# 942            CAM    HUILA  SEGUIMIENTO  LAM3703  07/06/2007
# 943    CORPOBOYACA   BOYACA  SEGUIMIENTO  LAM1994  17/12/2003
# 944    CORPOBOYACA   BOYACA  SEGUIMIENTO  LAM1994  17/12/2003
# 945            CAM    HUILA  SEGUIMIENTO  LAM3779  25/07/2007
#
#                    MUNIC                                           PROYECTO  \
# 0    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 1    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 2    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 3                EL PASO  LICENCIA AMBIENTAL GLOBAL PARA EL PROYECTO CAM...
# 4                EL PASO  LICENCIA AMBIENTAL GLOBAL PARA EL PROYECTO CAM...
# ..                   ...                                                ...
# 941              PALERMO                      POZO EXPLORATORIO GUANABANA-2
# 942              PALERMO                      POZO EXPLORATORIO GUANABANA-1
# 943        PUERTO BOYACA                                       POZO BALSO-1
# 944        PUERTO BOYACA                                     POZO MORICHE-1
# 945                 AIPE                       POZO EXPLORATORIO ARRAYAN-1.
#
#          REGION  RESOLUCION                                 SOLICITANT  \
# 0      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 1      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 2      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 3         NORTE      2563.0          TEXICAN OIL LTD SUCURSAL COLOMBIA
# 4         NORTE      2563.0          TEXICAN OIL LTD SUCURSAL COLOMBIA
# ..          ...         ...                                        ...
# 941  CENTRO SUR      1007.0                                 HOCOL S.A.
# 942  CENTRO SUR      1007.0                                 HOCOL S.A.
# 943      CENTRO      1378.0             MANSAROVAR ENERGY COLOMBIA LTD
# 944      CENTRO      1378.0             MANSAROVAR ENERGY COLOMBIA LTD
# 945  CENTRO SUR      1318.0                             ECOPETROL S.A.
#
#                       geometry
# 0    POINT (-76.22626 1.14385)
# 1    POINT (-76.23612 1.13818)
# 2    POINT (-76.22893 1.14162)
# 3    POINT (-73.68522 9.70236)
# 4    POINT (-73.67319 9.71454)
# ..                         ...
# 941  POINT (-75.38347 2.77870)
# 942  POINT (-75.38787 2.76720)
# 943  POINT (-74.53784 6.17697)
# 944  POINT (-74.53605 6.19696)
# 945  POINT (-75.29862 3.17782)
#
# [946 rows x 11 columns]

# %%
# Print all the entries in the 'SOLICITANT' column using .to_string(index=False)

# %%
# Plot Oil and Gas (2013) Locations on the Colombia boundary using Matplotlib
fig, ax = plt.subplots(figsize=(20,10))

colombia_gdf.plot(ax =ax, edgecolor ="black", color= "beige")

oil_gdf.plot(ax =ax, marker ='^', color = "green", markersize = 40)
plt.title( "Oil & Gas in Colombia 2023")
plt.show()

# %% [markdown]
# ## **Rivers**

# %%
# Open Colombia rivers
rivers_url = ("https://maps.princeton.edu/download/file/tufts-colombia-major-rivers-11-shapefile.zip")

# Open rivers using geopandas
rivers_gdf = gpd.read_file(rivers_url)
rivers_gdf
# Out:
#                  gml_id              nombre_geo symbol  \
# 0      Drenaje_DobleQ.1             RÍO BANADIA      3
# 1      Drenaje_DobleQ.2         RÍO SAN BARTOLO      3
# 2      Drenaje_DobleQ.3  BRAZUELO DE LA ROMPIDA      3
# 3      Drenaje_DobleQ.4                     NaN      3
# 4      Drenaje_DobleQ.5                  Estero    NaN
# ..                  ...                     ...    ...
# 272  Drenaje_DobleQ.263                RÍO TOLA      3
# 273  Drenaje_DobleQ.264         ESTERO SECADERO      3
# 274  Drenaje_DobleQ.265                     NaN      3
# 275  Drenaje_DobleQ.266               RÍO PATÍA      3
# 276  Drenaje_DobleQ.272        QUEBRADA BARRERA      3
#
#                                               geometry
# 0    POLYGON ((-71.77688 6.98672, -71.77690 6.98673...
# 1    POLYGON ((-74.39558 6.68462, -74.39369 6.68327...
# 2    POLYGON ((-73.98540 7.23822, -73.98589 7.23747...
# 3    POLYGON ((-71.58675 6.46682, -71.58673 6.46678...
# 4    POLYGON ((-70.76271 5.50627, -70.76281 5.50574...
# ..                                                 ...
# 272  POLYGON ((-78.28576 2.60301, -78.28437 2.58979...
# 273  POLYGON ((-78.28165 2.43932, -78.28157 2.44015...
# 274  POLYGON ((-77.64400 2.93037, -77.64378 2.92925...
# 275  POLYGON ((-78.41314 2.18721, -78.41418 2.18572...
# 276  POLYGON ((-78.50477 2.50733, -78.50347 2.50717...
#
# [277 rows x 4 columns]

# %%
# Examine the data using .info()
rivers_gdf.info()

# Print the rivers Coordinate Reference System (CRS)
rivers_gdf.crs
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gml_id      277 non-null    object
#  1   nombre_geo  259 non-null    object
#  2   symbol      276 non-null    object
#  3   geometry    277 non-null    geometry
# dtypes: geometry(1), object(3)
# memory usage: 8.8+ KB
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Plot the rivers data using .plot()
rivers_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## **Roads**

# %%
# Open Columbia roads (850,000 entries!)
roads_url = ("https://maps.princeton.edu/download/file/tufts-colombia-roads-11-shapefile.zip")

# Open the roads data using geopandas
roads_gdf = gpd.read_file(roads_url)
roads_gdf.head()
# Out:
#    tipo_via estado_sup numero_car accesibili nombre_geo clas_tipov  \
# 0       6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 1       6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 2       6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 3       5.0       3306       3502       3601        NaN          5
# 4       1.0       3301       3501       3600        NaN          1
#
#       esc_vis  type                                           geometry
# 0         0.0     3  LINESTRING (-70.48271 4.24664, -70.48295 4.245...
# 1         0.0     3  LINESTRING (-70.50524 4.26742, -70.50498 4.267...
# 2         0.0     3  LINESTRING (-70.19799 4.24444, -70.19862 4.243...
# 3         0.0     3  LINESTRING (-67.45190 3.51188, -67.45173 3.513...
# 4  17000000.0     1  LINESTRING (-76.01828 1.87813, -76.00653 1.880...

# %%
# Explore data using .info()
roads_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 11400 entries, 0 to 11399
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tipo_via    11400 non-null  float64
#  1   estado_sup  11400 non-null  object
#  2   numero_car  11400 non-null  object
#  3   accesibili  11400 non-null  object
#  4   nombre_geo  11 non-null     object
#  5   clas_tipov  11202 non-null  object
#  6   esc_vis     11400 non-null  float64
#  7   type        11400 non-null  int64
#  8   geometry    11400 non-null  geometry
# dtypes: float64(2), geometry(1), int64(1), object(5)
# memory usage: 801.7+ KB

# %% [markdown]
# ## **Airports**

# %%
# Download Airports data
col_airports_url = "https://maps.princeton.edu/download/file/tufts-colombia-mainairports-14-shapefile.zip"

# Open airports data using geopandas
col_airports_gdf = gpd.read_file(col_airports_url)
col_airports_gdf.head()
# Out:
#           gml_id  id_aero                                           nombre  \
# 0  Aeropuertos.1      1.0                 AEROPUERTO INTERNACIONAL EL EDÉN
# 1  Aeropuertos.2      2.0       AEROPUERTO INTERNACIONAL ERNESTO CORTISSOZ
# 2  Aeropuertos.3      3.0               AEROPUERTO INTERNACIONAL EL DORADO
# 3  Aeropuertos.4      4.0               AEROPUERTO INTERNACIONAL PALONEGRO
# 4  Aeropuertos.5      5.0  AEROPUERTO INTERNACIONAL ALFONSO BONILLA ARAGÓN
#
#             tipo administra          estadocon  n_desti_in cod_iata cod_oaci  \
# 0  INTERNACIONAL        ANI  EN ESTRUCTURACION         1.0      AXM     SKAR
# 1  INTERNACIONAL        ANI  EN ESTRUCTURACION         3.0      BAQ     SKBQ
# 2  INTERNACIONAL        ANI       CONCESIONADO        51.0      BOG     SKBO
# 3  INTERNACIONAL        ANI       CONCESIONADO         1.0      BGA     SKBG
# 4  INTERNACIONAL        ANI       CONCESIONADO         8.0      CLO     SKCL
#
#      ciudad_loc    municipio       departamen     observacio        latitud  \
# 0       ARMENIA   LA TEBAIDA          QUINDÍO  INTERNACIONAL  04°27'09.99 N
# 1  BARRANQUILLA      SOLEDAD        ATLÁNTICO  INTERNACIONAL  10°53'22.52 N
# 2   BOGOTÁ D.C.  BOGOTÁ D.C.      BOGOTÁ D.C.  INTERNACIONAL  04°42'05.74 N
# 3   BUCARAMANGA      LEBRIJA        SANTANDER  INTERNACIONAL  07°07'35.40 N
# 4          CALI      PALMIRA  VALLE DEL CAUCA  INTERNACIONAL  03°32'35.60 N
#
#         longitud  lat_decima  long_decim            mi_style  \
# 0  75°45'59.21 O    4.452775  -75.766447  Symbol (35, 0, 12)
# 1  74°46'50.95 O   10.889589  -74.780819  Symbol (35, 0, 12)
# 2  74°08'49.01 O    4.701594  -74.146947  Symbol (35, 0, 12)
# 3  73°11'05.20 O    7.126500  -73.184778  Symbol (35, 0, 12)
# 4  76°22'53.70 O    3.543222  -76.381583  Symbol (35, 0, 12)
#
#                      geometry
# 0   POINT (-75.76645 4.45278)
# 1  POINT (-74.78082 10.88959)
# 2   POINT (-74.14695 4.70159)
# 3   POINT (-73.18478 7.12650)
# 4   POINT (-76.38158 3.54322)

# %%
# Determine number of airport types per admin designation using pd.crosstab()
pd.crosstab(col_airports_gdf.tipo, col_airports_gdf.administra)
# Out:
# administra               AEROCIVIL  ANI
# tipo
# INTERNACIONAL                    2   11
# MILITAR                          7    0
# NACIONAL                         7   10
# NACIONAL - REGIONAL             33    1
# REGIONAL                         1    0
# REGIONAL - NO PASAJEROS         16    1

# %%
cross_tab = pd.crosstab(col_airports_gdf["tipo"], col_airports_gdf["administra"])
cross_tab
# Out:
# administra               AEROCIVIL  ANI
# tipo
# INTERNACIONAL                    2   11
# MILITAR                          7    0
# NACIONAL                         7   10
# NACIONAL - REGIONAL             33    1
# REGIONAL                         1    0
# REGIONAL - NO PASAJEROS         16    1

# %%
cross_tab = pd.crosstab(col_airports_gdf["administra"], col_airports_gdf["tipo"])
cross_tab
# Out:
# tipo        INTERNACIONAL  MILITAR  NACIONAL  NACIONAL - REGIONAL  REGIONAL  \
# administra
# AEROCIVIL               2        7         7                   33         1
# ANI                    11        0        10                    1         0
#
# tipo        REGIONAL - NO PASAJEROS
# administra
# AEROCIVIL                        16
# ANI                               1

# %%
# Plot the airports data using .plot()
col_airports_gdf.plot()
# Out:
# <Axes: >

# %%
# Looking at airport data as csv (pandas df) [from the previous notebook]
col_airports_df = pd.read_csv("https://ourairports.com/countries/CO/airports.csv")
col_airports_df
# Out:
#          id    ident            type  \
# 0      6104     SKBO   large_airport
# 1      6109     SKCG  medium_airport
# 2      6158     SKRG  medium_airport
# 3      6110     SKCL  medium_airport
# 4      6105     SKBQ  medium_airport
# ..      ...      ...             ...
# 726   45104  CO-0003        heliport
# 727   45105  CO-0004        heliport
# 728   45115  CO-0014        heliport
# 729   45101     SKSF          closed
# 730  353413  CO-0072        heliport
#
#                                              name  latitude_deg  \
# 0                 El Dorado International Airport      4.701590
# 1              Rafael Nuñez International Airport     10.442400
# 2        Jose Maria Córdova International Airport      6.164540
# 3    Alfonso Bonilla Aragon International Airport      3.543220
# 4         Ernesto Cortissoz International Airport     10.889600
# ..                                            ...           ...
# 726                Banco De La Republica Heliport      1.196944
# 727                Banco De La Republica Heliport      5.697500
# 728                      Cofa Roldanillo Heliport      4.413611
# 729                 Santa Fé de Antioquía Airport      6.500631
# 730      Carlos Haime University Hospital Helipad     10.508400
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -74.146900        8361.0       NaN     Colombia          CO  ...
# 1       -75.513000           4.0        SA     Colombia          CO  ...
# 2       -75.423100        6955.0        SA     Colombia          CO  ...
# 3       -76.381600        3162.0        SA     Colombia          CO  ...
# 4       -74.780800          98.0        SA     Colombia          CO  ...
# ..             ...           ...       ...          ...         ...  ...
# 726     -77.280000           NaN        SA     Colombia          CO  ...
# 727     -76.665000           NaN        SA     Colombia          CO  ...
# 728     -76.143333           NaN        SA     Colombia          CO  ...
# 729     -75.822521        1500.0        SA     Colombia          CO  ...
# 730     -75.467660          20.0        SA     Colombia          CO  ...
#
#               municipality scheduled_service gps_code iata_code  local_code  \
# 0                   Bogota                 1     SKBO       BOG         BOG
# 1                Cartagena                 1     SKCG       CTG         CTG
# 2                 Medellín                 1     SKRG       MDE         MDE
# 3                     Cali                 1     SKCL       CLO         CLO
# 4             Barranquilla                 1     SKBQ       BAQ         BAQ
# ..                     ...               ...      ...       ...         ...
# 726                  Pasto                 0      NaN       NaN         BNC
# 727                 Quibdo                 0      NaN       NaN         BND
# 728             Roldanillo                 0      NaN       NaN         ICR
# 729  Santa Fé de Antioquía                 0      NaN       NaN         NaN
# 730         Serena del Mar                 0      NaN       NaN         NaN
#
#                         home_link  \
# 0          https://eldorado.aero/
# 1                             NaN
# 2                             NaN
# 3    https://www.aerocali.com.co/
# 4                             NaN
# ..                            ...
# 726                           NaN
# 727                           NaN
# 728                           NaN
# 729                           NaN
# 730                           NaN
#
#                                         wikipedia_link  \
# 0    https://en.wikipedia.org/wiki/El_Dorado_Intern...
# 1    https://en.wikipedia.org/wiki/Rafael_N%C3%BA%C...
# 2    https://en.wikipedia.org/wiki/Jos%C3%A9_Mar%C3...
# 3    https://en.wikipedia.org/wiki/Alfonso_Bonilla_...
# 4    https://en.wikipedia.org/wiki/Ernesto_Cortisso...
# ..                                                 ...
# 726                                                NaN
# 727                                                NaN
# 728                                                NaN
# 729                                                NaN
# 730                                                NaN
#
#                            keywords  score               last_updated
# 0                      Cundinamarca  51275  2023-12-15T12:55:30+00:00
# 1                               NaN    750  2009-10-20T10:46:09+00:00
# 2                               NaN    750  2017-08-14T21:49:57+00:00
# 3    Palmaseca International, 02-20    750  2019-08-15T00:05:28+00:00
# 4                               NaN    750  2009-10-20T10:46:07+00:00
# ..                              ...    ...                        ...
# 726                             NaN      0  2012-06-09T11:20:37+00:00
# 727                             NaN      0  2012-06-09T11:07:51+00:00
# 728                             NaN      0  2012-06-09T12:06:00+00:00
# 729                 SKSF, SKSF, SFA      0  2016-03-11T19:36:26+00:00
# 730                             NaN      0  2022-03-08T20:56:28+00:00
#
# [731 rows x 23 columns]

# %%
# Looking at airport data as csv (pandas df)
#col_airports_df = pd.read_csv("https://ourairports.com/countries/CO/airports.csv")


# Create geodataframe from pandas df
coordinates = gpd.points_from_xy(
    col_airports_df.longitude_deg,
    col_airports_df.latitude_deg)

col_airports_gdf2 = gpd.GeoDataFrame(
    data=col_airports_df,
    geometry=coordinates)

# Convert to shp
col_airports_gdf2.to_file("col_airports.shp")

col_airports_gdf2.crs
# Out:
# /tmp/ipykernel_1504/1012209934.py:15: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   col_airports_gdf2.to_file("col_airports.shp")

# %%
col_airports_gdf2
# Out:
#          id    ident            type  \
# 0      6104     SKBO   large_airport
# 1      6109     SKCG  medium_airport
# 2      6158     SKRG  medium_airport
# 3      6110     SKCL  medium_airport
# 4      6105     SKBQ  medium_airport
# ..      ...      ...             ...
# 726   45104  CO-0003        heliport
# 727   45105  CO-0004        heliport
# 728   45115  CO-0014        heliport
# 729   45101     SKSF          closed
# 730  353413  CO-0072        heliport
#
#                                              name  latitude_deg  \
# 0                 El Dorado International Airport      4.701590
# 1              Rafael Nuñez International Airport     10.442400
# 2        Jose Maria Córdova International Airport      6.164540
# 3    Alfonso Bonilla Aragon International Airport      3.543220
# 4         Ernesto Cortissoz International Airport     10.889600
# ..                                            ...           ...
# 726                Banco De La Republica Heliport      1.196944
# 727                Banco De La Republica Heliport      5.697500
# 728                      Cofa Roldanillo Heliport      4.413611
# 729                 Santa Fé de Antioquía Airport      6.500631
# 730      Carlos Haime University Hospital Helipad     10.508400
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -74.146900        8361.0       NaN     Colombia          CO  ...
# 1       -75.513000           4.0        SA     Colombia          CO  ...
# 2       -75.423100        6955.0        SA     Colombia          CO  ...
# 3       -76.381600        3162.0        SA     Colombia          CO  ...
# 4       -74.780800          98.0        SA     Colombia          CO  ...
# ..             ...           ...       ...          ...         ...  ...
# 726     -77.280000           NaN        SA     Colombia          CO  ...
# 727     -76.665000           NaN        SA     Colombia          CO  ...
# 728     -76.143333           NaN        SA     Colombia          CO  ...
# 729     -75.822521        1500.0        SA     Colombia          CO  ...
# 730     -75.467660          20.0        SA     Colombia          CO  ...
#
#     scheduled_service gps_code iata_code local_code  \
# 0                   1     SKBO       BOG        BOG
# 1                   1     SKCG       CTG        CTG
# 2                   1     SKRG       MDE        MDE
# 3                   1     SKCL       CLO        CLO
# 4                   1     SKBQ       BAQ        BAQ
# ..                ...      ...       ...        ...
# 726                 0      NaN       NaN        BNC
# 727                 0      NaN       NaN        BND
# 728                 0      NaN       NaN        ICR
# 729                 0      NaN       NaN        NaN
# 730                 0      NaN       NaN        NaN
#
#                         home_link  \
# 0          https://eldorado.aero/
# 1                             NaN
# 2                             NaN
# 3    https://www.aerocali.com.co/
# 4                             NaN
# ..                            ...
# 726                           NaN
# 727                           NaN
# 728                           NaN
# 729                           NaN
# 730                           NaN
#
#                                         wikipedia_link  \
# 0    https://en.wikipedia.org/wiki/El_Dorado_Intern...
# 1    https://en.wikipedia.org/wiki/Rafael_N%C3%BA%C...
# 2    https://en.wikipedia.org/wiki/Jos%C3%A9_Mar%C3...
# 3    https://en.wikipedia.org/wiki/Alfonso_Bonilla_...
# 4    https://en.wikipedia.org/wiki/Ernesto_Cortisso...
# ..                                                 ...
# 726                                                NaN
# 727                                                NaN
# 728                                                NaN
# 729                                                NaN
# 730                                                NaN
#
#                            keywords  score               last_updated  \
# 0                      Cundinamarca  51275  2023-12-15T12:55:30+00:00
# 1                               NaN    750  2009-10-20T10:46:09+00:00
# 2                               NaN    750  2017-08-14T21:49:57+00:00
# 3    Palmaseca International, 02-20    750  2019-08-15T00:05:28+00:00
# 4                               NaN    750  2009-10-20T10:46:07+00:00
# ..                              ...    ...                        ...
# 726                             NaN      0  2012-06-09T11:20:37+00:00
# 727                             NaN      0  2012-06-09T11:07:51+00:00
# 728                             NaN      0  2012-06-09T12:06:00+00:00
# 729                 SKSF, SKSF, SFA      0  2016-03-11T19:36:26+00:00
# 730                             NaN      0  2022-03-08T20:56:28+00:00
#
#                        geometry
# 0     POINT (-74.14690 4.70159)
# 1    POINT (-75.51300 10.44240)
# 2     POINT (-75.42310 6.16454)
# 3     POINT (-76.38160 3.54322)
# 4    POINT (-74.78080 10.88960)
# ..                          ...
# 726   POINT (-77.28000 1.19694)
# 727   POINT (-76.66500 5.69750)
# 728   POINT (-76.14333 4.41361)
# 729   POINT (-75.82252 6.50063)
# 730  POINT (-75.46766 10.50840)
#
# [731 rows x 24 columns]

# %%
# Select only international, military and national airports from col_airports_gdf
airport_types = ["INTERNACIONAL", "MILITAR", "NACIONAL"]

inter_mil_nat = col_airports_gdf[
    col_airports_gdf["tipo"].isin(airport_types)]
inter_mil_nat.head()
# Out:
#           gml_id  id_aero                                           nombre  \
# 0  Aeropuertos.1      1.0                 AEROPUERTO INTERNACIONAL EL EDÉN
# 1  Aeropuertos.2      2.0       AEROPUERTO INTERNACIONAL ERNESTO CORTISSOZ
# 2  Aeropuertos.3      3.0               AEROPUERTO INTERNACIONAL EL DORADO
# 3  Aeropuertos.4      4.0               AEROPUERTO INTERNACIONAL PALONEGRO
# 4  Aeropuertos.5      5.0  AEROPUERTO INTERNACIONAL ALFONSO BONILLA ARAGÓN
#
#             tipo administra          estadocon  n_desti_in cod_iata cod_oaci  \
# 0  INTERNACIONAL        ANI  EN ESTRUCTURACION         1.0      AXM     SKAR
# 1  INTERNACIONAL        ANI  EN ESTRUCTURACION         3.0      BAQ     SKBQ
# 2  INTERNACIONAL        ANI       CONCESIONADO        51.0      BOG     SKBO
# 3  INTERNACIONAL        ANI       CONCESIONADO         1.0      BGA     SKBG
# 4  INTERNACIONAL        ANI       CONCESIONADO         8.0      CLO     SKCL
#
#      ciudad_loc    municipio       departamen     observacio        latitud  \
# 0       ARMENIA   LA TEBAIDA          QUINDÍO  INTERNACIONAL  04°27'09.99 N
# 1  BARRANQUILLA      SOLEDAD        ATLÁNTICO  INTERNACIONAL  10°53'22.52 N
# 2   BOGOTÁ D.C.  BOGOTÁ D.C.      BOGOTÁ D.C.  INTERNACIONAL  04°42'05.74 N
# 3   BUCARAMANGA      LEBRIJA        SANTANDER  INTERNACIONAL  07°07'35.40 N
# 4          CALI      PALMIRA  VALLE DEL CAUCA  INTERNACIONAL  03°32'35.60 N
#
#         longitud  lat_decima  long_decim            mi_style  \
# 0  75°45'59.21 O    4.452775  -75.766447  Symbol (35, 0, 12)
# 1  74°46'50.95 O   10.889589  -74.780819  Symbol (35, 0, 12)
# 2  74°08'49.01 O    4.701594  -74.146947  Symbol (35, 0, 12)
# 3  73°11'05.20 O    7.126500  -73.184778  Symbol (35, 0, 12)
# 4  76°22'53.70 O    3.543222  -76.381583  Symbol (35, 0, 12)
#
#                      geometry
# 0   POINT (-75.76645 4.45278)
# 1  POINT (-74.78082 10.88959)
# 2   POINT (-74.14695 4.70159)
# 3   POINT (-73.18478 7.12650)
# 4   POINT (-76.38158 3.54322)

# %%
# Create map of Colombia boundaries, rivers, airports, and roads on the same axis using Matplotlib
fig, ax = plt.subplots(figsize=(12,20))


colombia_gdf.plot(
    ax=ax,
    color='beige',
    edgecolor='black',
    linewidth=0.1)

rivers_gdf.plot(
    ax=ax,
    linewidth=1,
    color='blue',
    alpha=0.9)

col_airports_gdf2.plot(
    ax=ax,
    markersize=40,
    edgecolor='black',
    #column='type',
    #legend=True,
    zorder=4)

roads_gdf.plot(ax=ax, color='black', linewidth=0.5, alpha=0.5)

plt.title('Rivers, Roads & Airports of Colombia', fontsize=20)
plt.show()

# %%
# Conservation Areas
conservation_url = "https://maps.princeton.edu/download/file/tufts-colombia-prioritizedenvconsareas-12-shapefile.zip"

conservation_gdf = gpd.read_file(conservation_url)
conservation_gdf
# Out:
#        OBJECTID  FID_ECOSIN  COUNT_  \
# 0             1          33     3.0
# 1             2          34     1.0
# 2             3          35     1.0
# 3             4          38     2.0
# 4             5          38     2.0
# ...         ...         ...     ...
# 16432     16433       69486     5.0
# 16433     16434       69486     5.0
# 16434     16435       69486     5.0
# 16435     16436       69486     5.0
# 16436     16437       69486     5.0
#
#                                               FIRST_ECOS  \
# 0      Aguas cont. naturales del helobioma Amazonia y...
# 1      Aguas cont. naturales del helobioma Amazonia y...
# 2       Lagunas costeras del helobioma Pacífico y Atrato
# 3      Aguas cont. naturales del helobioma Amazonia y...
# 4      Aguas cont. naturales del helobioma Amazonia y...
# ...                                                  ...
# 16432  Aguas cont. naturales del helobioma Pacífico y...
# 16433  Aguas cont. naturales del helobioma Pacífico y...
# 16434  Aguas cont. naturales del helobioma Pacífico y...
# 16435  Aguas cont. naturales del helobioma Pacífico y...
# 16436  Aguas cont. naturales del helobioma Pacífico y...
#
#                                               UNIDAD_ANA PRIORIDAD  \
# 0      Guyana Yari_Miriti Helobiomas de la Amazonia y...         h
# 1      Amazonia Caguan_Florencia Helobiomas de la Ama...         g
# 2      NorAndina Valle_seco_Patia Helobiomas del Pací...         d
# 3      Guyana Vaupes Helobiomas de la Amazonia y Orin...         h
# 4      Guyana Vaupes Helobiomas de la Amazonia y Orin...         h
# ...                                                  ...       ...
# 16432  Choco_Magdalena Atrato Helobiomas del Pacífico...         g
# 16433  Choco_Magdalena Atrato Helobiomas del Pacífico...         g
# 16434  Choco_Magdalena Atrato Helobiomas del Pacífico...         g
# 16435  Choco_Magdalena Atrato Helobiomas del Pacífico...         g
# 16436  Choco_Magdalena Atrato Helobiomas del Pacífico...         g
#
#         SHAPE_Leng                         explica_pr  \
# 0      1535.638403  baja insuficiencia y sin urgencia
# 1        65.931033       baja insuficiencia y urgente
# 2        21.960951             omisiones sin urgencia
# 3         3.960279  baja insuficiencia y sin urgencia
# 4        53.027423  baja insuficiencia y sin urgencia
# ...            ...                                ...
# 16432    13.326469       baja insuficiencia y urgente
# 16433     1.257992       baja insuficiencia y urgente
# 16434     4.448094       baja insuficiencia y urgente
# 16435     1.220483       baja insuficiencia y urgente
# 16436     5.010973       baja insuficiencia y urgente
#
#                                                 geometry
# 0      MULTIPOLYGON (((-69.72375 -1.29256, -69.72305 ...
# 1      MULTIPOLYGON (((-74.57031 -0.11575, -74.57036 ...
# 2      POLYGON ((-77.78335 1.88468, -77.78381 1.88448...
# 3      POLYGON ((-72.77739 2.57914, -72.77742 2.57949...
# 4      POLYGON ((-72.76568 2.58083, -72.76507 2.58073...
# ...                                                  ...
# 16432  POLYGON ((-77.02930 7.71022, -77.02930 7.71028...
# 16433  POLYGON ((-77.11124 7.44756, -77.10682 7.44793...
# 16434  MULTIPOLYGON (((-77.08465 7.47795, -77.08562 7...
# 16435  MULTIPOLYGON (((-77.07257 7.51067, -77.07105 7...
# 16436  MULTIPOLYGON (((-76.79976 6.94844, -76.79967 6...
#
# [16437 rows x 9 columns]

# %%
# Forest areas
forest_url = "https://maps.princeton.edu/download/file/tufts-colombia-forest-reserves-12-shapefile.zip"

forest_gdf = gpd.read_file(forest_url)
forest_gdf
# Out:
#                              nombre_zrf       area_ha  \
# 0                              Pacífico  8.069757e+06
# 1          Sierra Nevada de Santa Marta  5.262357e+05
# 2  RFN_L2°_59 Serranía de Los Motilones  5.219028e+05
# 3                                 Cocuy  7.158414e+05
# 4                               Central  1.496513e+06
# 5                         Río Magdalena  2.125560e+06
# 6                              Amazonia  3.492608e+07
#
#                      nombre_z_1     area_ha_1  \
# 0                      Pacífico  8.047495e+06
# 1  Sierra Nevada de Santa Marta  5.280525e+05
# 2     Serranía de Los Motilones  5.241259e+05
# 3                         Cocuy  7.204282e+05
# 4                       Central  1.495426e+06
# 5                 Río Magdalena  2.130886e+06
# 6                      Amazonia  3.519454e+07
#
#                                             geometry
# 0  MULTIPOLYGON (((-76.31857 8.26714, -76.31750 8...
# 1  MULTIPOLYGON (((-73.24657 10.51653, -73.24657 ...
# 2  MULTIPOLYGON (((-73.08240 9.56633, -73.08216 9...
# 3  POLYGON ((-72.47034 7.48265, -72.46925 7.48238...
# 4  MULTIPOLYGON (((-75.13256 5.81325, -75.13190 5...
# 5  MULTIPOLYGON (((-74.77991 7.16391, -74.77991 7...
# 6  MULTIPOLYGON (((-67.64612 3.82720, -67.64566 3...

# %%
# Plot the conservation areas using .plot() and color by 'PRIORIDAD'
conservation_gdf.plot(column="PRIORIDAD",
                      legend=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# <Axes: >

# %%
# Plot Colombia boundaries and forested areas colored by 'nombre_zrf' on same axis using Matplotlib
fig, ax = plt.subplots(figsize=(12,10))
forest_gdf.plot(column="nombre_zrf", legend=True,ax=ax)
colombia_gdf.plot(ax=ax, color='None')
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# <Axes: >

# %%
# Mining Areas
mining_url = "https://maps.princeton.edu/download/file/tufts-colombia-miningprojects-13-shapefile.zip"
mining_gdf = gpd.read_file(mining_url)
mining_gdf.plot()
# Out:
# <Axes: >

# %%
# Petroleum / Gas exploration 2014 - *Polygon
gas_2014_url = "https://maps.princeton.edu/download/file/tufts-colombia-petroleumgasexplorationareas-14-shapefile.zip"

# Open data using geopandas and plot using .plot() color by 'SOLICITANT'
gas_2014_gdf = gpd.read_file(gas_2014_url)
gas_2014_gdf.plot(column="SOLICITANT", figsize=(12,10))
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# <Axes: >

# %%
# Plot the oil and gas (2014) polygon on the Colombia boundary using Matplotlib
gas_2014_gdf
# Out:
#         CORPORACIO              DEPTO       ESTADO      EXP       FECHA  \
# 0              NaN       COSTA AFUERA  SEGUIMIENTO  LAM4701  01/07/2011
# 1             CDMB          SANTANDER    ARCHIVADO  LAM1059  28/09/1998
# 2    CORPORINOQUIA           CASANARE    ARCHIVADO  LAM0651  30/08/1996
# 3    CORPORINOQUIA  CASANARE Y BOYACA    ARCHIVADO  LAM1231  30/07/1998
# 4    CORPORINOQUIA           CASANARE    ARCHIVADO  LAM1284  28/07/1998
# ..             ...                ...          ...      ...         ...
# 664            CAM              HUILA  SEGUIMIENTO  LAM2245  20/10/2000
# 665     CORPOCESAR              CESAR  SEGUIMIENTO  LAM5771  06/03/2013
# 666     CORPOCESAR              CESAR  SEGUIMIENTO  LAM5547  07/06/2013
# 667     CORPOCESAR              CESAR  SEGUIMIENTO  LAM5771  06/03/2013
# 668  CORPOAMAZONIA           PUTUMAYO  SEGUIMIENTO  LAM4990    28/08/12
#
#                                          MUNIC  \
# 0                                          NaN
# 1                              GIRON Y LEBRIJA
# 2                                      AGUAZUL
# 3    YOPAL, AGUAZUL, PAJARITO Y LABRANZAGRANDE
# 4                                      AGUAZUL
# ..                                         ...
# 664                                        NaN
# 665                                  AGUACHICA
# 666                         AGUACHICA, GAMARRA
# 667                                  AGUACHICA
# 668               SAN MIGUEL, VALLE DEL GUAMEZ
#
#                                               PROYECTO      REGION  \
# 0    PERFORACION EXPLORATORIA COSTA AFUERA DE LOS B...  MAR CARIBE
# 1    AREA DE INTERES DE PERFORACION EXPLORATORIA GU...       NORTE
# 2                      BLOQUE DE EXPLORACION LA CABAÑA   ORINOQUIA
# 3                AREA DE PERFORACION EXPLORATORIA DELE   ORINOQUIA
# 4    AREA DE POZOS DE DESARROLLO MULTIPLES DENOMINA...   ORINOQUIA
# ..                                                 ...         ...
# 664                            AREA DE INTERES MATAMBO         SUR
# 665      AREA DE PÉRFORACION EXPLORATORIA SANTA ISABEL      CARIBE
# 666  AREA PERFORACIONEXPLORATORIA VALLE MEDIO MAGDA...      CARIBE
# 667      AREA DE PÉRFORACION EXPLORATORIA SANTA ISABEL      CARIBE
# 668  PERFORACIÓN EXPLORATORIA PARA UN ÁREA DE INTER...         SUR
#
#      RESOLUCION                                        SOLICITANT  \
# 0        1315.0                            EQUION ENERGIA LIMITED
# 1         921.0                                  TRITON RESOURCES
# 2         945.0                                     ECOPETROL S.A
# 3         702.0            BP EXPLORATION COMPANY (COLOMBIA) LTD.
# 4         685.0            BP EXPLORATION COMPANY (COLOMBIA) LTD.
# ..          ...                                               ...
# 664      1061.0                                        HOCOL S.A.
# 665       220.0                     GREEN POWER SUCURSAL COLOMBIA
# 666       551.0                         LEWIS ENERGY COLOMBIA INC
# 667       220.0                     GREEN POWER SUCURSAL COLOMBIA
# 668       715.0  GRUPO C & C ENERGÍA (BARBADOS) SUCURSAL COLOMBIA
#
#                              OBSERVACIO SUB  Shape_Leng  \
# 0                                   NaN   1  237.084152
# 1                                   NaN   1   40.026316
# 2                                   NaN   1   50.026122
# 3                                   NaN   1   41.012352
# 4                                   NaN   1    4.000000
# ..                                  ...  ..         ...
# 664  AREA DE INTERES BLOQUE SAN JACINTO   3   35.389217
# 665                                 NaN   3   27.895931
# 666                                 NaN   3  102.603970
# 667                                 NaN   3    0.000000
# 668                                 NaN   3   14.086835
#
#                                               geometry
# 0    POLYGON ((-75.33289 10.87122, -75.55129 10.683...
# 1    POLYGON ((-73.32203 7.26157, -73.28386 7.23726...
# 2    POLYGON ((-72.50175 4.97512, -72.50135 5.14029...
# 3    POLYGON ((-72.60429 5.36117, -72.55126 5.41871...
# 4    POLYGON ((-72.69454 5.04123, -72.69003 5.04122...
# ..                                                 ...
# 664  POLYGON ((-75.57643 2.41697, -75.57615 2.41683...
# 665  POLYGON ((-73.72442 8.18584, -73.71938 8.18702...
# 666  POLYGON ((-73.70831 8.43879, -73.70833 8.41661...
# 667                                               None
# 668  POLYGON ((-76.83817 0.30179, -76.83748 0.30213...
#
# [669 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(12,10))
colombia_gdf.plot(ax=ax, color='None')
gas_2014_gdf.plot(ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## **Focusing on one Department (Cauca)**
#
#
# *   Select Department
# *   Clip roads, rivers, airports to Cauca
# *   Plot all layers on common axis

# %%
# Select Cauca
cauca = dept_gdf[dept_gdf["NAME_1"].isin(["Cauca"])]
cauca
# Out:
#      ID_0  ISO    NAME_0  ID_1 NAME_1  ID_2                  NAME_2    HASC_2  \
# 406    53  COL  Colombia    11  Cauca   407                Almaguer  CO.CA.AL
# 407    53  COL  Colombia    11  Cauca   408                 Argelia  CO.CA.AG
# 408    53  COL  Colombia    11  Cauca   409                  Balboa  CO.CA.BA
# 409    53  COL  Colombia    11  Cauca   410                 Bolívar  CO.CA.BO
# 410    53  COL  Colombia    11  Cauca   411            Buenos Aires  CO.CA.BA
# 411    53  COL  Colombia    11  Cauca   412                 Cajibío  CO.CA.CJ
# 412    53  COL  Colombia    11  Cauca   413                 Caldonó  CO.CA.CD
# 413    53  COL  Colombia    11  Cauca   414                  Caloto  CO.CA.CT
# 414    53  COL  Colombia    11  Cauca   415                 Corinto  CO.CA.CO
# 415    53  COL  Colombia    11  Cauca   416                El Tambo  CO.CA.ET
# 416    53  COL  Colombia    11  Cauca   417               Florencia  CO.CA.FL
# 417    53  COL  Colombia    11  Cauca   418                   Guapí  CO.CA.GU
# 418    53  COL  Colombia    11  Cauca   419                    Inzá  CO.CA.IN
# 419    53  COL  Colombia    11  Cauca   420                 Jambaló  CO.CA.JA
# 420    53  COL  Colombia    11  Cauca   421               La Sierra  CO.CA.LS
# 421    53  COL  Colombia    11  Cauca   422                 La Vega  CO.CA.LV
# 422    53  COL  Colombia    11  Cauca   423          López de Micay  CO.CA.LO
# 423    53  COL  Colombia    11  Cauca   424              Mercaderes  CO.CA.ME
# 424    53  COL  Colombia    11  Cauca   425                 Miranda  CO.CA.MI
# 425    53  COL  Colombia    11  Cauca   426                 Morales  CO.CA.MS
# 426    53  COL  Colombia    11  Cauca   427                    Páez  CO.CA.PZ
# 427    53  COL  Colombia    11  Cauca   428                 Padilla  CO.CA.PD
# 428    53  COL  Colombia    11  Cauca   429                   Patía  CO.CA.PA
# 429    53  COL  Colombia    11  Cauca   430                Piendamó  CO.CA.PI
# 430    53  COL  Colombia    11  Cauca   431                 Popayán  CO.CA.PO
# 431    53  COL  Colombia    11  Cauca   432           Puerto Tejada  CO.CA.PT
# 432    53  COL  Colombia    11  Cauca   433                  Puracé  CO.CA.PU
# 433    53  COL  Colombia    11  Cauca   434                   Rosas  CO.CA.RO
# 434    53  COL  Colombia    11  Cauca   435           San Sebastián  CO.CA.SS
# 435    53  COL  Colombia    11  Cauca   436              Santa Rosa  CO.CA.SR
# 436    53  COL  Colombia    11  Cauca   437  Santander de Quilichao  CO.CA.SN
# 437    53  COL  Colombia    11  Cauca   438                  Silvia  CO.CA.SI
# 438    53  COL  Colombia    11  Cauca   439                  Sotará  CO.CA.SO
# 439    53  COL  Colombia    11  Cauca   440                  Suárez  CO.CA.SU
# 440    53  COL  Colombia    11  Cauca   441                  Timbío  CO.CA.TM
# 441    53  COL  Colombia    11  Cauca   442                Timbiquí  CO.CA.TQ
# 442    53  COL  Colombia    11  Cauca   443                 Toribío  CO.CA.TR
# 443    53  COL  Colombia    11  Cauca   444                  Totoró  CO.CA.TT
#
#      CCN_2  CCA_2     TYPE_2     ENGTYPE_2  NL_NAME_2 VARNAME_2  \
# 406      0    NaN  Municipio  Municipality        NaN       NaN
# 407      0    NaN  Municipio  Municipality        NaN       NaN
# 408      0    NaN  Municipio  Municipality        NaN       NaN
# 409      0    NaN  Municipio  Municipality        NaN       NaN
# 410      0    NaN  Municipio  Municipality        NaN       NaN
# 411      0    NaN  Municipio  Municipality        NaN       NaN
# 412      0    NaN  Municipio  Municipality        NaN       NaN
# 413      0    NaN  Municipio  Municipality        NaN       NaN
# 414      0    NaN  Municipio  Municipality        NaN       NaN
# 415      0    NaN  Municipio  Municipality        NaN       NaN
# 416      0    NaN  Municipio  Municipality        NaN       NaN
# 417      0    NaN  Municipio  Municipality        NaN       NaN
# 418      0    NaN  Municipio  Municipality        NaN       NaN
# 419      0    NaN  Municipio  Municipality        NaN       NaN
# 420      0    NaN  Municipio  Municipality        NaN       NaN
# 421      0    NaN  Municipio  Municipality        NaN       NaN
# 422      0    NaN  Municipio  Municipality        NaN     López
# 423      0    NaN  Municipio  Municipality        NaN       NaN
# 424      0    NaN  Municipio  Municipality        NaN       NaN
# 425      0    NaN  Municipio  Municipality        NaN       NaN
# 426      0    NaN  Municipio  Municipality        NaN       NaN
# 427      0    NaN  Municipio  Municipality        NaN       NaN
# 428      0    NaN  Municipio  Municipality        NaN  El Bordo
# 429      0    NaN  Municipio  Municipality        NaN       NaN
# 430      0    NaN  Municipio  Municipality        NaN       NaN
# 431      0    NaN  Municipio  Municipality        NaN       NaN
# 432      0    NaN  Municipio  Municipality        NaN       NaN
# 433      0    NaN  Municipio  Municipality        NaN       NaN
# 434      0    NaN  Municipio  Municipality        NaN       NaN
# 435      0    NaN  Municipio  Municipality        NaN       NaN
# 436      0    NaN  Municipio  Municipality        NaN       NaN
# 437      0    NaN  Municipio  Municipality        NaN       NaN
# 438      0    NaN  Municipio  Municipality        NaN       NaN
# 439      0    NaN  Municipio  Municipality        NaN       NaN
# 440      0    NaN  Municipio  Municipality        NaN       NaN
# 441      0    NaN  Municipio  Municipality        NaN       NaN
# 442      0    NaN  Municipio  Municipality        NaN       NaN
# 443      0    NaN  Municipio  Municipality        NaN       NaN
#
#                                               geometry
# 406  POLYGON ((-76.91900 1.79490, -76.92480 1.80130...
# 407  POLYGON ((-77.40909 2.21342, -77.40870 2.21860...
# 408  POLYGON ((-77.24387 1.96429, -77.24660 1.96730...
# 409  POLYGON ((-76.91090 1.63080, -76.91490 1.63320...
# 410  POLYGON ((-76.63720 2.87270, -76.64530 2.87740...
# 411  POLYGON ((-76.92880 2.75840, -76.92130 2.75490...
# 412  POLYGON ((-76.39680 2.77990, -76.40940 2.78050...
# 413  POLYGON ((-76.29110 3.08990, -76.29370 3.08730...
# 414  POLYGON ((-76.09200 3.05930, -76.09950 3.05710...
# 415  POLYGON ((-76.80070 2.45290, -76.80530 2.44200...
# 416  POLYGON ((-77.07230 1.73840, -77.06600 1.72450...
# 417  MULTIPOLYGON (((-77.32278 2.37790, -77.31770 2...
# 418  POLYGON ((-75.98150 2.47200, -75.99310 2.47550...
# 419  POLYGON ((-76.23590 2.77230, -76.24860 2.76950...
# 420  POLYGON ((-76.76710 2.14780, -76.77740 2.14780...
# 421  POLYGON ((-76.62870 2.05650, -76.62810 2.05360...
# 422  MULTIPOLYGON (((-77.65569 2.94597, -77.65598 2...
# 423  POLYGON ((-77.10730 1.68165, -77.12130 1.67510...
# 424  POLYGON ((-76.10010 3.16390, -76.10930 3.15930...
# 425  POLYGON ((-76.92880 2.75840, -76.92880 2.77690...
# 426  POLYGON ((-75.98150 2.47200, -75.99190 2.47730...
# 427  POLYGON ((-76.30650 3.22720, -76.30940 3.21680...
# 428  POLYGON ((-76.97510 2.11860, -76.98610 2.11350...
# 429  POLYGON ((-76.54200 2.68120, -76.53910 2.67830...
# 430  POLYGON ((-76.44900 2.38100, -76.45360 2.38270...
# 431  POLYGON ((-76.42870 3.21670, -76.43450 3.21960...
# 432  POLYGON ((-76.36300 2.14440, -76.36470 2.13740...
# 433  POLYGON ((-76.64931 2.24331, -76.65760 2.23920...
# 434  POLYGON ((-76.62280 1.89300, -76.62910 1.88440...
# 435  POLYGON ((-76.17240 1.52720, -76.18450 1.52380...
# 436  POLYGON ((-76.63720 2.87270, -76.62970 2.89350...
# 437  POLYGON ((-76.49750 2.61800, -76.49870 2.62320...
# 438  POLYGON ((-76.54350 2.35650, -76.55160 2.33520...
# 439  POLYGON ((-76.74440 2.81830, -76.75530 2.81720...
# 440  POLYGON ((-76.69050 2.42700, -76.69630 2.41210...
# 441  MULTIPOLYGON (((-77.76820 2.76292, -77.76791 2...
# 442  POLYGON ((-76.29110 3.08990, -76.28910 3.09190...
# 443  POLYGON ((-76.31625 2.35562, -76.31520 2.35040...

# %%
# Select Florencia (Municipio)
florencia = cauca[cauca["NAME_2"].isin(["Florencia"])]
florencia
# Out:
#      ID_0  ISO    NAME_0  ID_1 NAME_1  ID_2     NAME_2    HASC_2  CCN_2  \
# 416    53  COL  Colombia    11  Cauca   417  Florencia  CO.CA.FL      0
#
#      CCA_2     TYPE_2     ENGTYPE_2  NL_NAME_2 VARNAME_2  \
# 416    NaN  Municipio  Municipality        NaN       NaN
#
#                                               geometry
# 416  POLYGON ((-77.07230 1.73840, -77.06600 1.72450...

# %%
# Print the CRS for Cacua and the rivers_gdf data
print(cauca.crs)
print(rivers_gdf.crs)
# Out:
# EPSG:4326
# GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]

# %%
# Reproject rivers_gdf to Cauca CRS (EPSG:4326)
rivers_4326 = rivers_gdf.to_crs("EPSG:4326")
print(rivers_4326.crs)
rivers_4326
# Out:
# EPSG:4326
#                  gml_id              nombre_geo symbol  \
# 0      Drenaje_DobleQ.1             RÍO BANADIA      3
# 1      Drenaje_DobleQ.2         RÍO SAN BARTOLO      3
# 2      Drenaje_DobleQ.3  BRAZUELO DE LA ROMPIDA      3
# 3      Drenaje_DobleQ.4                     NaN      3
# 4      Drenaje_DobleQ.5                  Estero    NaN
# ..                  ...                     ...    ...
# 272  Drenaje_DobleQ.263                RÍO TOLA      3
# 273  Drenaje_DobleQ.264         ESTERO SECADERO      3
# 274  Drenaje_DobleQ.265                     NaN      3
# 275  Drenaje_DobleQ.266               RÍO PATÍA      3
# 276  Drenaje_DobleQ.272        QUEBRADA BARRERA      3
#
#                                               geometry
# 0    POLYGON ((-71.77688 6.98672, -71.77690 6.98673...
# 1    POLYGON ((-74.39558 6.68462, -74.39369 6.68327...
# 2    POLYGON ((-73.98540 7.23822, -73.98589 7.23747...
# 3    POLYGON ((-71.58675 6.46682, -71.58673 6.46678...
# 4    POLYGON ((-70.76271 5.50627, -70.76281 5.50574...
# ..                                                 ...
# 272  POLYGON ((-78.28576 2.60301, -78.28437 2.58979...
# 273  POLYGON ((-78.28165 2.43932, -78.28157 2.44015...
# 274  POLYGON ((-77.64400 2.93037, -77.64378 2.92925...
# 275  POLYGON ((-78.41314 2.18721, -78.41418 2.18572...
# 276  POLYGON ((-78.50477 2.50733, -78.50347 2.50717...
#
# [277 rows x 4 columns]

# %%
# Clip rivers to Cauca boundary using gpd.clip() and plot using .plot()
cauca_rivers = gpd.clip(rivers_4326, cauca)
cauca_rivers.plot()
# Out:
# <Axes: >

# %%
# Reproject col_airports_gdf to Cauca CRS
airports_4326 = col_airports_gdf.to_crs("EPSG:4326")
print(airports_4326.crs)
airports_4326

# Clip airports to Cauca boundary
cauca_aero = gpd.clip(airports_4326, cauca)
cauca_aero

# Plot Cauca airports
cauca_aero.plot()
# Out:
# EPSG:4326
# <Axes: >

# %%
# Reproject oil/gas to Cauca CRS
og_4326 = oil_gdf.to_crs("EPSG:4326")
print(og_4326.crs)


# Clip oil & gas to Cauca
cauca_oil_gas = gpd.clip(og_4326, cauca)
cauca_oil_gas
# Out:
# EPSG:4326
#         CORPORACIO     DEPTO       ESTADO      EXP       FECHA  \
# 866  CORPOAMAZONIA  PUTUMAYO  SEGUIMIENTO  LAM0042  18/05/1995
# 864  CORPOAMAZONIA  PUTUMAYO  SEGUIMIENTO  LAM0042  18/05/1995
# 865  CORPOAMAZONIA     CAUCA  SEGUIMIENTO  LAM0042  18/05/1995
# 867  CORPOAMAZONIA  PUTUMAYO  SEGUIMIENTO  LAM0042  18/05/1995
# 1    CORPOAMAZONIA   CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 2    CORPOAMAZONIA   CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 0    CORPOAMAZONIA   CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
#
#                    MUNIC                                           PROYECTO  \
# 866                  NaN                         POZO DE DESARROLLO LINDA-5
# 864        PUERTO GUZMAN                      POZO DE DESARROLLO TOROYACO-5
# 865             PIAMONTE                      POZO DE DESARROLLO TOROYACO-4
# 867                MOCOA                         POZO DE DESARROLLO LINDA-4
# 1    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 2    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 0    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
#
#        REGION  RESOLUCION                                 SOLICITANT  \
# 866  AMAZONIA       472.0                GRAN TIERRA ENERGY COLOMBIA
# 864  AMAZONIA       472.0                GRAN TIERRA ENERGY COLOMBIA
# 865  AMAZONIA       472.0                GRAN TIERRA ENERGY COLOMBIA
# 867  AMAZONIA       472.0                GRAN TIERRA ENERGY COLOMBIA
# 1    AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 2    AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 0    AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
#
#                       geometry
# 866  POINT (-76.47776 0.99100)
# 864  POINT (-76.47122 0.99240)
# 865  POINT (-76.30377 0.99311)
# 867  POINT (-76.51284 1.00903)
# 1    POINT (-76.23612 1.13818)
# 2    POINT (-76.22893 1.14162)
# 0    POINT (-76.22626 1.14385)

# %%
# Reproject roads to Cauca CRS



# Clip roads to Cauca

# %%
# Plot roads, rivers, oil & gas within Cauca
fig, ax = plt.subplots(figsize=(16, 40))
cauca.plot(ax=ax,
           edgecolor='black',
           color='linen')
cauca_rivers.plot(ax=ax,
                color='cornflowerblue',
                linewidth=0.8)
cauca_aero.plot(ax=ax,
                color='black',
                marker="X",
                markersize=400,
                zorder=4)

cauca_oil_gas.plot(ax=ax,
                   edgecolor='black',
                   marker="o",
                   markersize=400,
                   alpha=0.5,
                   zorder=4)

#plt.legend(loc="upper left")
plt.title("Gas & Petroleum Extraction Sites (2013)\nCauca Department, Colombia", fontsize=30)
plt.show()

# %% [markdown]
# ## **Focus on one municipality (Puetro Asis)**

# %%
# Zoom in on PUERTO ASÍS

# Extract PUERTO ASÍS from Putumayo boundary
puerto_asis = colombia_gdf[colombia_gdf["NOM_MUNICI"].isin(["PUERTO ASÍS"])]
puerto_asis

# Clip oil gas points 2013 to PUERTO ASÍS boundary
puerto_asis_oil_gas = gpd.clip(oil_gdf, puerto_asis)
puerto_asis_oil_gas

# Clip rivers to PUERTO ASÍS boundary
puerto_asis_rivers = gpd.clip(rivers_gdf, puerto_asis)
puerto_asis_rivers

# Clip roads to PUERTO ASÍS boundary
puerto_asis_roads = gpd.clip(roads_gdf, puerto_asis)
puerto_asis_roads

# Clip airports to PUERTO ASÍS boundary
puerto_asis_airports = gpd.clip(col_airports_gdf, puerto_asis)
puerto_asis_airports

# Clip gas/oil polygon 2014 to PUERTO ASÍS boundary
puerto_asis_gas_2014 = gpd.clip(gas_2014_gdf, puerto_asis)
puerto_asis_gas_2014

# Plot Puerto Asis boundary and clipped oil and gas
fig, ax = plt.subplots(figsize=(12,6))
puerto_asis.plot(ax=ax, color='beige', edgecolor='grey')
puerto_asis_oil_gas.plot(ax=ax, color='dimgrey', edgecolor='black', markersize=60)
puerto_asis_rivers.plot(ax=ax, color='blue')
puerto_asis_roads.plot(ax=ax, color='grey')
puerto_asis_airports.plot(ax=ax, marker="X", markersize=300, color='red', edgecolor='black')
puerto_asis_gas_2014.plot(ax=ax, column="SOLICITANT", legend=True, alpha=0.5)

# Define and place legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.3, 1.0, 0., 0.))

ax.set(title="Petroleum and Gas Exraction Sites (2013) and Exploration Areas (2014); Airport (X); Rivers, Roads \nPuerto Asís Municipality, Putumayo")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 24
#      21 puerto_asis_airports
#      23 # Clip gas/oil polygon 2014 to PUERTO ASÍS boundary
# ---> 24 puerto_asis_gas_2014 = gpd.clip(gas_2014_gdf, puerto_asis)
#      25 puerto_asis_gas_2014
#      27 # Plot Puerto Asis boundary and clipped oil and gas
#
# NameError: name 'gas_2014_gdf' is not defined

# %% [markdown]
# ## **Interactive Maps with Folium**

# %%
# Create an interactive map of airports using folium

import folium

#Define coordinates of where we want to center our map
map_center_coords = [5.0, -72.0]

#Create the map
my_map = folium.Map(location = map_center_coords, zoom_start = 6)

# for lat,long in zip(bigger_air_and_heli.geometry.y, bigger_air_and_heli.geometry.x):
#     folium.Marker(
#         location=[lat, long],
#         #popup=['name']
#     ).add_to(my_map)

for _, airport_info in inter_mil_nat.iterrows():
    folium.Marker(
        location=[airport_info.geometry.y, airport_info.geometry.x],
        popup=airport_info['nombre']
    ).add_to(my_map)

my_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 17
#       9 my_map = folium.Map(location = map_center_coords, zoom_start = 6)
#      11 # for lat,long in zip(bigger_air_and_heli.geometry.y, bigger_air_and_heli.geometry.x):
#      12 #     folium.Marker(
#      13 #         location=[lat, long],
#      14 #         #popup=['name']
#      15 #     ).add_to(my_map)
# ---> 17 for _, airport_info in inter_mil_nat.iterrows():
#      18     folium.Marker(
#      19         location=[airport_info.geometry.y, airport_info.geometry.x],
#      20         popup=airport_info['nombre']
#      21     ).add_to(my_map)
#      23 my_map
#
# NameError: name 'inter_mil_nat' is not defined

# %% [markdown]
# ## **Looking at Geology Data** (hosted on CyVerse)

# %%
# Open Geology of S America gdf

geology_url = (
    "https://data.cyverse.org/dav-anon/iplant/home/shared/"
    "earthlab/geopark/geo6ag.zip")

geology_gdf = gpd.read_file(geology_url)
geology_gdf

# %%
# Clip S America geology to Colombia boundary

geog_clipped = geology_gdf.clip(cauca.geometry)
geog_clipped

# %%
# Plot clipped geology
fig, ax = plt.subplots(figsize=(12,20))
geog_clipped.plot(ax=ax,
                  column='GLG',
                  legend=True)
plt.title("Geologic Map of Cauca Deptartmento Colombia", fontsize=25)
plt.show()
